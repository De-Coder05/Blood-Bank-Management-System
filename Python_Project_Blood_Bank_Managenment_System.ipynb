# %% [markdown]
# <a href="https://colab.research.google.com/github/De-Coder05/Blood-Bank-Management-System/blob/main/Python_Project_Blood_Bank_Managenment_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""import os
import platform
import mysql.connector
import datetime"""
global z
import random
import sys
"""mydb=mysql.connector.connect(user='root',password='1234',host='localhost',database='bbms')
if mydb.is_connected()==True:
    print("Connection Successful")
else:
    print("Error")
mycursor=mydb.cursor()"""
print("Welcome to Blood Bank Management System...")
reci_id=random.randrange(10000,11000)
bdid=random.randrange(150000,160500)
reci_name=input("Enter Name:")
reci_sex=input("Enter Your Gender(M/F):")
dob=input("Enter your date of birth:")
ph=int(input("Enter your phone number:"))
email=input("Enter your email:")
ch=input("Patient Or Donor (p/d)")
def register():
    P=[]
    D=[]
    if ch=="p":
        P.append(reci_id)
        P.append(reci_name)
        reci_age=int(input("Enter Age: "))
        P.append(reci_age)
        reci_Bgroup=input("Enter Blood Group: ")
        P.append(reci_Bgroup)
        P.append(reci_sex)
        reci_reg_date=input("Enter Today's Date: ")
        P.append(reci_reg_date)
        #mycursor.execute("insert into recipient(reci_id,reci_name,reci_age,reci_Bgroup,reci_sex,reci_reg_date)values ({},'{}','{}','{}','{}','{}')".format(reci_id,reci_name,reci_age,reci_Bgroup,reci_sex,reci_reg_date))
        print(P)
        print("Patient Details Added Successfully...")
        print("Your Generated Id is ",reci_id)
        #mydb.commit()
    else:
        D.append(bdid)
        D.append(reci_name)
        bdage=int(input("Enter Age: "))
        D.append(bdage)
        bdsex=input("Enter Gender: ")
        D.append(bdsex)
        bd_Bgroup=input("Enter Blood Group: ")
        D.append(bd_Bgroup)
        bd_regdate=input("Enter Today's Date: ")
        D.append(bd_regdate)
        #mycursor.execute("insert into blood_donor(bdid,bdname,bdage,bdsex,bd_Bgroup,bd_regdate)values ({},'{}','{}','{}','{}','{}')".format(bdid,reci_name,bdage,bdsex,bd_Bgroup,bd_regdate))
        #mydb.commit()
        print("Patient Details Added Successfully...")
        if bdage<18 or bdage>=65:
            print("Sorry..You are not in the appropriate age to donate blood")
            exit()
        print("Your Generated Id is ",bdid)

def availabilityp():
    if ch=="p":
        print("We have the following types of Blood Groups available with us at the moment..")
        print("1. A")
        print("2. O+")
        print("3. AB+")
        print("4. B+")
        print("5. AB-")
        print("6. O-")
        print("7. B-")
        print("8. AB")
        x=int(input("Enter The Choice: "))
        y=random.randrange(1,21)
        z=y+5
        print("Sure..We have enrolled you for blood donation and your alloted number is",y)
        print("...We request you to please wait",z,"minutes...")
def eligibilityd():
    wt=[]
    ID=int(input("Enter Your Alloted ID: "))
    if ch=="d":
        print("We request you to enter the following details in order for us to check whether you are eligible for blood donation...")
        a=int(input("Enter Your Weight in Kg: "))
        wt.append(a)
        b=int(input("Enter Your Height in cm: "))
        wt.append(b)
        #mycursor.execute("insert into BMI(Id,Name,Weight,Height_cm)values({},'{}',{},{})".format(ID,reci_name,a,b))
        #mydb.commit()
        c=b/100
        d=c**2
        BMI=a/d
        print("Your BMI is", BMI)
        if reci_sex=="m"or reci_sex=="M":
            if BMI<18.5:
                print("You Are Underweight and we recommend you not to donate blood..")
            elif BMI>=18.5 and BMI<25:
                print("Yay! You lie in normal BMI range..You are eligible for blood donation")
            else:
                print("You are above the normal BMI range..You are eligible for blood donation")
        else:
            if BMI<17.5:
                print("You Are Underweight and we recommend you not to donate blood..")
            elif BMI>=17.5 and BMI<24:
                print("Yay! You lie in normal BMI range..You are eligible for blood donation")
            else:
                print("You are above the normal BMI range..You are eligible for blood donation")

def availabilityd():
    if ch=="d":
        y=random.randrange(1,21)
        z=y+5
        print("Sure..We have enrolled you for blood donation and your alloted number is",y)
        print("...We request you to please wait",z,"minutes...")
        print("Donor Number",y,"is requested to reach lab number",random.randrange(1,11),"....")

def packagep():
    pgp=[]
    s=1500
    print("We have the following packages available for you (In addition to recieving blood and Fever Extensive Package): ")
    print("The cost of receiving blood and Fever extensive package is Rs 1500 ..which is mandatory")
    print("1. HbA1c ---------------------> Rs.500")
    print("2. Allergy Screening Test ----> Rs.1000")
    print("3. CRP Test ------------------> Rs.600")
    x=input("Do you want to add the first test ?(y/n):")
    Y=input("Do you want to add the second test ?(y/n):")
    z=input("Do you want to add the third test ?(y/n):")
    if x=="y" and Y=="y" and z=="n":
       s=s+1500
    elif x=="y" and Y=="n" and z=="y":
       s=s+1100
    elif x=="n" and Y=="y" and z=="y":
       s=s+1600
    elif x=="n" and Y=="n" and z=="y":
       s=s+600
    elif x=="y" and Y=="n" and z=="n":
       s=s+500
    elif x=="n" and Y=="y" and z=="n":
       s=s+1000
    elif x=="y" and Y=="y" and z=="y":
       s=s+2100
    elif x=="n" and Y=="n" and z=="n":
       s=s+0
    #mycursor.execute("insert into package(ID,Name,HbA1c,Allergy_test,CRP_test)values({},'{}','{}','{}','{}')".format(reci_id,reci_name,x,Y,z))
    #mydb.commit()

def costp():
    print("Here Are Some Convenient Methods To Pay: ")
    print("1. Credit Card")
    print("2. Debit Card")
    print("3. Digital Banking")
    print("4. Cash")
    k=int(input("Enter The Choice: "))
    if k==1 or k==2:
        b=int(input("Enter Your 4 Digit PIN: "))
        if b in range(1000,10000):
            print("Payment Successful")
        else:
            print("Payment Unsuccessful..Try Again")
    elif k==3:
        ph=int(input("Enter Your Phone Number: "))
        print("Processing...")
        if ph in range(1000000000,100000000000):
            b=int(input("Enter Your 4 Digit PIN: "))
            if b in range(1000,10000):
                print("Payment Successful")
            else:
                print("Payment Unsuccessful..Try Again")
        else:
            print("Payment Unsuccessful..Try Again")
    elif k==4:
        print("Payment Successful")
    else:
        print("Wrong Input")
    print("Thank you for visiting our centre ...Hope you liked it :)")

def diseased ():
    print("We would like to know .. if you have had any of the following diseases in the past years ..")
    print("1.Heart disease")
    print("2.Typhoid")
    print("3.Dengue")
    print("4.Malaria")
    print("5.Covid-19")
    print("6.NO! I AM HEALTHY:)")
    chp=int(input("Choose from the following choices:"))
    if chp== 1:
        print("We would like to ask you some questions regarding your present health..")
        a=input("Do you feel pain in your chest on a regular basis?(y/n):")
        b=input("Do you feel shortness of breath on a regular basis?(y/n):")
        c=input("Do you have palpitations (fast/uneven heartbeats) on a frequent basis?(y/n):")
        d=input("Do you have swelling in your legs,ankels?(y/n):")
        if a=="y" or b=="y" or c=="y"or d=="y":
            disease="Heart disease"
            print("We are sorry but you aren't eligible for blood donation due to precautionary policies of our blood bank.")
        elif a=="n" or b=="n" or c=="n"or d=="n":
            print("You are physicaly fit and eligible for blood donation !!")
        elif a=="n" or b=="y" or c=="n"or d=="n":
            print("You are eligible for blood donation !")
        else:
            print("We are sorry but you aren't eligible for blood donation due to precautionary policies of our blood bank.")
    elif chp==2:
        print("We would to ask you some questions regarding your present health..")
        a=input("Do you feel pain in your abdomen on a regular basis?(y/n):")
        b=input("Do you have high fever on a regular basis?(y/n):")
        c=input("Do you have vomitting on a frequent basis?(y/n):")
        d=input("Do you feel loss of appetite?(y/n):")
        if a=="y" or b=="y" or c=="y"or d=="y":
            disease="Typhoid"
            print("We are sorry but you aren't eligible for blood donation due to precautionary policies of our blood bank.")
        elif a=="n" or b=="n" or c=="n"or d=="n":
            print("You are physicaly fit and eligible for blood donation !!")
        elif a=="y" or b=="n" or c=="n"or d=="n":
            print("You are eligible for blood donation !")
        else:
            print("We are sorry but you aren't eligible for blood donation due to precautionary policies of our blood bank.")
    elif chp==3:
        print("We would to ask you some questions regarding your present health..")
        a=input("Do you feel fatigue on a regular basis?(y/n):")
        b=input("Do you feel loss of appetite?(y/n):")
        c=input("Do you have rashes on your body?(y/n):")
        d=input("Do you have pain in your joints or muscles on a regular basis?(y/n):")
        if a=="y" or b=="y" or c=="y"or d=="y":
            disease="Dengue"
            print("We are sorry but you aren't eligible for blood donation due to precautionary policies of our blood bank.")
        elif a=="n" or b=="n" or c=="n"or d=="n":
            print("You are physicaly fit and eligible for blood donation !!")
        elif a=="n" or b=="n" or c=="n"or d=="y":
            print("You are eligible for blood donation !")
        else:
            print("We are sorry but you aren't eligible for blood donation due to precautionary policies of our blood bank.")
    elif chp==4:
        print("We would to ask you some questions regarding your present health..")
        a=input("Do you feel fatigue on a regular basis?(y/n):")
        b=input("Do you have fever and night sweats?(y/n):")
        c=input("Do you have fast heart rate on a frequent basis?(y/n):")
        d=input("Do you have headache and pain in abdomen?(y/n):")
        if a=="y" or b=="y" or c=="y"or d=="y":
            disease="Malaria"
            print("We are sorry but you aren't eligible for blood donation due to precautionary policies of our blood bank.")
        elif a=="n" or b=="n" or c=="n"or d=="n":
            print("You are physicaly fit and eligible for blood donation !!")
        elif a=="n" or b=="n" or c=="n"or d=="y":
            print("You are eligible for blood donation !")
        else:
            print("We are sorry but you aren't eligible for blood donation due to precautionary policies of our blood bank.")
    elif chp==5:
        print("We would to ask you some questions regarding your present health..")
        a=input("Do you feel loss of taste and smell?(y/n):")
        b=input("Do you feel shortness of breath on a regular basis?(y/n):")
        c=input("Do you have sore throat?(y/n):")
        d=input("Do you have fever and chills?(y/n):")
        if a=="y" or b=="y" or c=="y"or d=="y":
            disease="covid-19"
            print("We are sorry but you aren't eligible for blood donation due to precautionary policies of our blood bank.")
        elif a=="n" or b=="n" or c=="n"or d=="n":
            print("You are physicaly fit and eligible for blood donation !!")
        elif a=="n" or b=="n" or c=="n"or d=="y":
            print("You are eligible for blood donation !")
        else:
            print("We are sorry but you aren't eligible for blood donation due to precautionary policies of our blood bank.")
    elif chp==6:
        print("VERY GOOD...You are physicaly fit and eligible for blood donation !!")
    #mycursor.execute("insert into disease(Name,Suspected_disease)values('{}','{}')".format(reci_name, disease))
    #mydb.commit()
def costd():
    print("Blood test price ---> Rs200")
    print("(Blood test + cetificate )price ---> Rs300")
    a=input("Do you want a certificate of appreciation?(y/n):")
    if a=="y":
        print("You have to pay the following amount ---> Rs300")
        print("Here Are Some Convenient Methods To Pay: ")
        print("1. Credit Card")
        print("2. Debit Card")
        print("3. Digital Banking")
        print("4. Cash")
        k=int(input("Enter The Choice: "))
        if k==1 or k==2:
            b=int(input("Enter Your 4 Digit PIN: "))
            if b in range(1000,10000):
                print("Payment Successful")
            else:
                print("Payment Unsuccessful..Try Again")
        elif k==3:
            ph=int(input("Enter Your Phone Number: "))
            print("Processing...")
            if ph in range(1000000000,100000000000):
                b=int(input("Enter Your 4 Digit PIN: "))
                if b in range(1000,10000):
                    print("Payment Successful")
                else:
                    print("Payment Unsuccessful..Try Again")
            else:
                print("Payment Unsuccessful..Try Again")
        elif k==4:
            print("Payment Successful")
        else:
            print("Wrong Input")
    print("Thank you for visiting our centre ...Please Leave Your Feedback :)")
    fdbck=input("Feedback(Type NA if none): ")
register()
if ch=="p":
       availabilityp()
       packagep()
       costp()
elif ch=="d":
       eligibilityd()
       availabilityd()
       diseased()
       costd()
# Out:
# Welcome to Blood Bank Management System...
# Enter Name:Devansh Wadhwani
# Enter Your Gender(M/F):M
# Enter your date of birth:05/05/2005
# Enter your phone number:8383922952
# Enter your email:dwadhwani_be23@thapar.edu
# Patient Or Donor (p/d)d
# Enter Age: 19
# Enter Gender: M
# Enter Blood Group: B+
# Enter Today's Date: 16/06/2024
# Patient Details Added Successfully...
# Your Generated Id is  159392
# Enter Your Alloted ID: 159392
# We request you to enter the following details in order for us to check whether you are eligible for blood donation...
# Enter Your Weight in Kg: 61
# Enter Your Height in cm: 178
# Your BMI is 19.252619618735007
# Yay! You lie in normal BMI range..You are eligible for blood donation
# Sure..We have enrolled you for blood donation and your alloted number is 10
# ...We request you to please wait 15 minutes...
# Donor Number 10 is requested to reach lab number 6 ....
# ...
